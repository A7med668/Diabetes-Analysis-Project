# %% [markdown]
# # Analysis of diabetes data
# Information about dataset attributes -
#
# Pregnancies: To express the Number of pregnancies
#
# Glucose: To express the Glucose level in blood
#
# BloodPressure: To express the Blood pressure measurement
#
# SkinThickness: To express the thickness of the skin
#
# Insulin: To express the Insulin level in blood
#
# BMI: To express the Body mass index
#
# DiabetesPedigreeFunction: To express the Diabetes percentage
#
# Age: To express the age
#
# Outcome: To express the final result 1 is Yes and 0 is No

# %% [markdown]
# # 1. Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Reading the dataset

# %%
data = pd.read_csv('diabetes.csv')

# %% [markdown]
# # 3. Data Analysis

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.head(10).style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# #T_4f9f2_row0_col0 {
#   background-color: #b2f396;
#   color: #000000;
# }
# #T_4f9f2_row0_col1 {
#   background-color: #acf59a;
#   color: #000000;
# }
# #T_4f9f2_row0_col2 {
#   background-color: #ffb360;
#   color: #000000;
# }
# #T_4f9f2_row0_col3, #T_4f9f2_row0_col5, #T_4f9f2_row4_col3 {
#   background-color: #ffa256;
#   color: #000000;
# }
# #T_4f9f2_row0_col4, #T_4f9f2_row1_col4, #T_4f9f2_row1_col8, #T_4f9f2_row2_col3, #T_4f9f2_row2_col4, #T_4f9f2_row3_col7, #T_4f9f2_row3_col8, #T_4f9f2_row4_col0, #T_4f9f2_row5_col3, #T_4f9f2_row5_col4, #T_4f9f2_row5_col8, #T_4f9f2_row6_col1, #T_4f9f2_row7_col2, #T_4f9f2_row7_col3, #T_4f9f2_row7_col4, #T_4f9f2_row7_col6, #T_4f9f2_row7_col8, #T_4f9f2_row9_col3, #T_4f9f2_row9_col4, #T_4f9f2_row9_col5 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_4f9f2_row0_col6 {
#   background-color: #0ca7ef;
#   color: #f1f1f1;
# }
# #T_4f9f2_row0_col7 {
#   background-color: #ff5f30;
#   color: #f1f1f1;
# }
# ...

# %%
data.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 322            0      124             70             20        0  27.4
# 38             2       90             68             42        0  38.2
# 708            9      164             78              0        0  32.8
# 490            2       83             65             28       66  36.8
# 196            1      105             58              0        0  24.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 322                     0.254   36        1
# 38                      0.503   27        1
# 708                     0.148   45        1
# 490                     0.629   24        0
# 196                     0.187   21        0

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.shape
# Out:
# (768, 9)

# %%
data.describe().columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.duplicated().any()
# Out:
# False

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # 4. Data Visualization

# %%
data['Outcome'].value_counts() # Outcome (0: No Diabetes, 1: Diabetes)
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_ratio = data['Outcome'].value_counts(normalize=True) * 100
print(f"Insight 12: Diabetes vs. Non-Diabetes Ratio:\n{diabetes_ratio}")
# Out:
# Insight 12: Diabetes vs. Non-Diabetes Ratio:
# Outcome
# 0    65.104167
# 1    34.895833
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.countplot(data = data ,x= data['Outcome'])
plt.xlabel('Outcome (0: No Diabetes, 1: Diabetes)')
plt.title('Diabetes vs. Non-Diabetes Ratio')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data[data['Outcome'] == 0]['Glucose'], label='No Diabetes', shade=True)
sns.kdeplot(data[data['Outcome'] == 1]['Glucose'], label='Diabetes', shade=True)
plt.title('Blood Glucose Distribution for Diabetic and Non-Diabetic Cases')
plt.xlabel('Glucose')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data[data['Outcome'] == 0]['Age'], label='No Diabetes', shade=True)
sns.kdeplot(data[data['Outcome'] == 1]['Age'], label='Diabetes', shade=True)
plt.title('Age Distribution for Diabetic and Non-Diabetic Cases')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data[data['Outcome'] == 0]['Insulin'], label='No Diabetes', shade=True)
sns.kdeplot(data[data['Outcome'] == 1]['Insulin'], label='Diabetes', shade=True)
plt.title('Insulin Levels Distribution for Diabetic and Non-Diabetic Cases')
plt.xlabel('Insulin Levels')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data[data['Outcome'] == 0]['BMI'], label='No Diabetes', shade=True)
sns.kdeplot(data[data['Outcome'] == 1]['BMI'], label='Diabetes', shade=True)
plt.title('BMI Distribution for Diabetic and Non-Diabetic Cases')
plt.xlabel('BMI')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
plt.figure(figsize=(10,6)) 
plt.title('Correlation Heatmap of Diabetes Features')
sns.heatmap(data.corr(),annot=True,fmt='0.1f', linewidth=0.5) 
plt.show()

# %%
data.corr()[["Pregnancies"	, "Glucose"]]
# Out:
#                           Pregnancies   Glucose
# Pregnancies                  1.000000  0.129459
# Glucose                      0.129459  1.000000
# BloodPressure                0.141282  0.152590
# SkinThickness               -0.081672  0.057328
# Insulin                     -0.073535  0.331357
# BMI                          0.017683  0.221071
# DiabetesPedigreeFunction    -0.033523  0.137337
# Age                          0.544341  0.263514
# Outcome                      0.221898  0.466581

# %%
plt.figure(figsize=(6,6)) 
sns.heatmap(data.corr()[["Pregnancies"	, "Glucose"]] ,annot=True,fmt='0.1f',linewidth=0.5) 
plt.show()

# %%
data.Insulin.value_counts().head(10)
# Out:
# Insulin
# 0      374
# 105     11
# 130      9
# 140      9
# 120      8
# 94       7
# 180      7
# 100      7
# 135      6
# 115      6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6)) 
data.Insulin.value_counts().head().plot(kind = 'pie') 
plt.show()
data.Insulin.value_counts().head().plot(kind = 'bar')
plt.show()

# %%
data['Pregnancies'].value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6)) 
plt.title("counter plot") 
sns.countplot(x='Pregnancies',data=data)
# Out:
# <Axes: title={'center': 'counter plot'}, xlabel='Pregnancies', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = data , x = "Pregnancies",  y = "Age" )
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Age'>

# %%
plt.subplot(1,3,1)
plt.title("Box plot")
sns.boxplot(y=data["DiabetesPedigreeFunction"])  
plt.show()

# %%
plt.figure(figsize=(6,6)) 
plt.title("Box plot")
sns.boxplot(data.Glucose)   
plt.show()

# %%
plt.figure(figsize=(6,6)) 
sns.boxplot(y='Glucose', data=data)
sns.stripplot(y='Glucose', data=data, color="k")
plt.show()

# %%
plt.figure(figsize=(6,6)) 
sns.boxplot(y='Insulin', data=data)
sns.stripplot(y='Insulin', data=data, color="k")
# Out:
# <Axes: ylabel='Insulin'>

# %%
plt.figure(figsize=(6,6)) 
sns.boxplot(y='Pregnancies', data=data)
sns.stripplot(y='Pregnancies', data=data, color="k")
# Out:
# <Axes: ylabel='Pregnancies'>

# %%
plt.figure(figsize=(16,12))
sns.set_style(style='whitegrid')
plt.subplot(3,3,1)
sns.boxplot(x='Glucose',data=data)
plt.subplot(3,3,2)
sns.boxplot(x='BloodPressure',data=data)
plt.subplot(3,3,3)
sns.boxplot(x='Insulin',data=data)
plt.subplot(3,3,4)
sns.boxplot(x='BMI',data=data)
plt.subplot(3,3,5)
sns.boxplot(x='Age',data=data)
plt.subplot(3,3,6)
sns.boxplot(x='SkinThickness',data=data)
plt.subplot(3,3,7)
sns.boxplot(x='Pregnancies',data=data)
plt.subplot(3,3,8)
sns.boxplot(x='DiabetesPedigreeFunction',data=data)
# Out:
# <Axes: xlabel='DiabetesPedigreeFunction'>

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='Age', y='BloodPressure', data=data)
plt.title('Scatter Plot of Age vs. BloodPressure')
plt.xlabel('Age')
plt.ylabel('BloodPressure')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='Insulin', y='DiabetesPedigreeFunction', data=data)
plt.title('Scatter Plot of Insulin vs. DiabetesPedigreeFunction')
plt.xlabel('Insulin')
plt.ylabel('DiabetesPedigreeFunction')
plt.show()

# %%
plt.figure(figsize=(6,6)) 
sns.scatterplot(x='Glucose', y='BloodPressure', data=data , hue='Outcome')
plt.title('Scatter Plot of Glucose vs. BloodPressure for Diabetic and Non-Diabetic Cases')
plt.xlabel('Glucose')
plt.ylabel('BloodPressure')
plt.show()

# %%
plt.figure(figsize=(6,6)) 
sns.scatterplot(x='DiabetesPedigreeFunction', y='Glucose', data=data , hue='Outcome', palette="husl")
plt.title('Scatter Plot of DiabetesPedigreeFunction vs. Glucose for Diabetic and Non-Diabetic Cases')
plt.xlabel('DiabetesPedigreeFunction')
plt.ylabel('Glucose')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='Age', y='BMI', data=data, hue='Outcome', palette="husl")
plt.title('Scatter Plot of Age vs. BMI for Diabetic and Non-Diabetic Cases')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.show()

# %%
plt.figure(figsize=(10,6)) 
sns.displot(data["BMI"])   
plt.show()

# %%
plt.figure(figsize=(10,6)) 
sns.displot(data["BloodPressure"])   
plt.show()

# %%
plt.figure(figsize=(6,6)) 
sns.distplot(data["BloodPressure"])  
plt.show()

# %%
plt.figure(figsize=(6,6)) 
sns.distplot(data['Glucose'])  
plt.show()

# %%
plt.figure(figsize=(6,6)) 
sns.distplot(data['DiabetesPedigreeFunction'])  
plt.show()

# %%
plt.figure(figsize=(6,6)) 
sns.lineplot(data=data , x= "BloodPressure" ,y= "Insulin", ci= None)
plt.show()

# %%
plt.figure(figsize=(6,6)) 
sns.lineplot(data=data , x= "BloodPressure" ,y= "DiabetesPedigreeFunction", ci= None)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x='Glucose', y='Insulin', data=data, scatter_kws={'s': 20}, line_kws={'color': 'red'})
plt.title('Relationship between Glucose and Insulin')
plt.xlabel('Glucose')
plt.ylabel('Insulin')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x='BMI', y='BloodPressure', data=data, scatter_kws={'s': 25}, line_kws={'color': 'black'})
plt.title('Relationship between BMI and BloodPressure')
plt.xlabel('BMI')
plt.ylabel('BloodPressure')
plt.show()

# %%
plt.figure(figsize=(20, 6))
#plot 1
plt.subplot(1, 3, 1)
plt.title("Countplot for Pregnancies")
sns.countplot(x='Pregnancies', data=data)

#plot 2
plt.title("Distribution plot for Pregnancies")
sns.displot(data["Pregnancies"])
plt.show()

#plot 3
plt.subplot(1, 3, 3)
plt.title("Boxplot for Pregnancies")
sns.boxplot(y=data["Pregnancies"])
plt.show()

# %%
data.hist(bins=25, edgecolor='black', linewidth=1.3, figsize=(10,10))
plt.show()

# %%
sns.pairplot(data, vars=["BloodPressure", "SkinThickness"])
plt.show()

# %%
sns.pairplot(data, vars=["BMI", "Glucose"])
plt.show()

# %%
sns.pairplot(data, vars=["Glucose", "Insulin"], hue='Outcome', markers=["o", "s"])
plt.show()

# %%
sns.pairplot(data, vars=["BMI", "SkinThickness"], hue='Outcome', markers=["o", "s"], palette="husl")
plt.show()

# %%
sns.pairplot(data)
